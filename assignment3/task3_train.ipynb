# %%
import importlib
import torch
import torch.nn as nn
from dataloaders import load_cifar10
import numpy as np

import trainer
import task2
import task3
import dataloaders
from trainer import Trainer, compute_loss_and_accuracy
from task2 import print_final_results, ExampleModel, create_plots, plot_comparison
from task3 import ModelX, ModelY, ModelZ

trainer = importlib.reload(trainer)
task2 = importlib.reload(task2)
task3 = importlib.reload(task3)
dataloaders = importlib.reload(dataloaders)

torch.manual_seed(17)

# %%
# NB: use SGD optimizer
epochs = 10
batch_size = 64
learning_rate = 1e-2
early_stop_count = 4
dataloaders = load_cifar10(batch_size)

model_base = ExampleModel(image_channels=3, num_classes=10)
trainer_base = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model_base,
    dataloaders
)
trainer_base.train()
# Out:
# Files already downloaded and verified
# Default transform
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Batches per seconds: 87.34, Global step:    351, Validation Loss: 1.97, Validation Accuracy: 0.293
# Epoch: 0, Batches per seconds: 90.94, Global step:    702, Validation Loss: 1.77, Validation Accuracy: 0.359
# Epoch: 1, Batches per seconds: 90.40, Global step:   1053, Validation Loss: 1.59, Validation Accuracy: 0.417
# Epoch: 1, Batches per seconds: 92.11, Global step:   1404, Validation Loss: 1.51, Validation Accuracy: 0.454
# Epoch: 2, Batches per seconds: 89.60, Global step:   1755, Validation Loss: 1.50, Validation Accuracy: 0.462
# Epoch: 2, Batches per seconds: 89.53, Global step:   2106, Validation Loss: 1.43, Validation Accuracy: 0.482
# Epoch: 3, Batches per seconds: 88.79, Global step:   2457, Validation Loss: 1.34, Validation Accuracy: 0.517
# Epoch: 3, Batches per seconds: 89.73, Global step:   2808, Validation Loss: 1.32, Validation Accuracy: 0.532
# Epoch: 4, Batches per seconds: 88.98, Global step:   3159, Validation Loss: 1.28, Validation Accuracy: 0.541
# Epoch: 4, Batches per seconds: 88.91, Global step:   3510, Validation Loss: 1.17, Validation Accuracy: 0.584
# Epoch: 5, Batches per seconds: 88.32, Global step:   3861, Validation Loss: 1.15, Validation Accuracy: 0.585
# Epoch: 5, Batches per seconds: 88.74, Global step:   4212, Validation Loss: 1.07, Validation Accuracy: 0.620
# Epoch: 6, Batches per seconds: 88.72, Global step:   4563, Validation Loss: 1.03, Validation Accuracy: 0.630
# Epoch: 6, Batches per seconds: 89.43, Global step:   4914, Validation Loss: 1.03, Validation Accuracy: 0.636
# Epoch: 7, Batches per seconds: 89.21, Global step:   5265, Validation Loss: 0.98, Validation Accuracy: 0.652
# Epoch: 7, Batches per seconds: 89.86, Global step:   5616, Validation Loss: 1.02, Validation Accuracy: 0.641
# Epoch: 8, Batches per seconds: 89.82, Global step:   5967, Validation Loss: 0.92, Validation Accuracy: 0.675
# Epoch: 8, Batches per seconds: 90.25, Global step:   6318, Validation Loss: 0.94, Validation Accuracy: 0.670
# Epoch: 9, Batches per seconds: 90.17, Global step:   6669, Validation Loss: 0.94, Validation Accuracy: 0.666
# Epoch: 9, Batches per seconds: 90.55, Global step:   7020, Validation Loss: 0.87, Validation Accuracy: 0.698

# %%
# NB: use SGD optimizer
epochs = 10
batch_size = 64
learning_rate = 1.5e-2
early_stop_count = 4
dataloaders_x = load_cifar10(batch_size, trans_opt='x')

model_x = ModelX(image_channels=3, num_classes=10)
trainer_x = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model_x,
    dataloaders_x
)
trainer_x.train()
# Out:
# Files already downloaded and verified
# Model X transform
# Files already downloaded and verified
# Files already downloaded and verified
# ModelX(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (spatial_normalizer): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Batches per seconds: 62.83, Global step:    703, Validation Loss: 1.77, Validation Accuracy: 0.366
# Epoch: 0, Batches per seconds: 64.47, Global step:   1406, Validation Loss: 1.47, Validation Accuracy: 0.456
# Epoch: 1, Batches per seconds: 62.63, Global step:   2109, Validation Loss: 1.35, Validation Accuracy: 0.520
# Epoch: 1, Batches per seconds: 63.18, Global step:   2812, Validation Loss: 1.21, Validation Accuracy: 0.564
# Epoch: 2, Batches per seconds: 62.83, Global step:   3515, Validation Loss: 1.04, Validation Accuracy: 0.635
# Epoch: 2, Batches per seconds: 63.10, Global step:   4218, Validation Loss: 0.98, Validation Accuracy: 0.651
# Epoch: 3, Batches per seconds: 62.69, Global step:   4921, Validation Loss: 0.91, Validation Accuracy: 0.685
# Epoch: 3, Batches per seconds: 63.26, Global step:   5624, Validation Loss: 0.88, Validation Accuracy: 0.688
# Epoch: 4, Batches per seconds: 63.17, Global step:   6327, Validation Loss: 0.83, Validation Accuracy: 0.704
# Epoch: 4, Batches per seconds: 63.48, Global step:   7030, Validation Loss: 0.78, Validation Accuracy: 0.724
# Epoch: 5, Batches per seconds: 63.44, Global step:   7733, Validation Loss: 0.74, Validation Accuracy: 0.740
# Epoch: 5, Batches per seconds: 64.05, Global step:   8436, Validation Loss: 0.73, Validation Accuracy: 0.750
# Epoch: 6, Batches per seconds: 64.32, Global step:   9139, Validation Loss: 0.71, Validation Accuracy: 0.754
# Epoch: 6, Batches per seconds: 64.70, Global step:   9842, Validation Loss: 0.67, Validation Accuracy: 0.764
# Epoch: 7, Batches per seconds: 64.68, Global step:  10545, Validation Loss: 0.66, Validation Accuracy: 0.773
# Epoch: 7, Batches per seconds: 64.80, Global step:  11248, Validation Loss: 0.61, Validation Accuracy: 0.787
# Epoch: 8, Batches per seconds: 64.80, Global step:  11951, Validation Loss: 0.60, Validation Accuracy: 0.792
# Epoch: 8, Batches per seconds: 64.98, Global step:  12654, Validation Loss: 0.59, Validation Accuracy: 0.796
# Epoch: 9, Batches per seconds: 65.01, Global step:  13357, Validation Loss: 0.56, Validation Accuracy: 0.802
# Epoch: 9, Batches per seconds: 65.16, Global step:  14060, Validation Loss: 0.53, Validation Accuracy: 0.819

# %%
# NB: use ADAM optimizer
epochs = 10
batch_size = 64
learning_rate = 1.5e-3
early_stop_count = 4
dataloaders_y = load_cifar10(batch_size, trans_opt='y')

model_y = ModelY(image_channels=3, num_classes=10)
trainer_y = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model_y,
    dataloaders_y
)
trainer_y.train()
# Out:
# Files already downloaded and verified
# Model Y transform
# Files already downloaded and verified
# ModelY(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (spatial_normalizer): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
#   (class_normalizer): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )
# Epoch: 0, Batches per seconds: 96.65, Global step:    351, Validation Loss: 1.29, Validation Accuracy: 0.543
# Epoch: 0, Batches per seconds: 103.42, Global step:    702, Validation Loss: 1.11, Validation Accuracy: 0.614
# Epoch: 1, Batches per seconds: 100.38, Global step:   1053, Validation Loss: 0.97, Validation Accuracy: 0.659
# Epoch: 1, Batches per seconds: 102.73, Global step:   1404, Validation Loss: 0.92, Validation Accuracy: 0.682
# Epoch: 2, Batches per seconds: 101.27, Global step:   1755, Validation Loss: 0.87, Validation Accuracy: 0.702
# Epoch: 2, Batches per seconds: 102.24, Global step:   2106, Validation Loss: 0.77, Validation Accuracy: 0.731
# Epoch: 3, Batches per seconds: 101.22, Global step:   2457, Validation Loss: 0.76, Validation Accuracy: 0.741
# Epoch: 3, Batches per seconds: 102.60, Global step:   2808, Validation Loss: 0.80, Validation Accuracy: 0.735
# Epoch: 4, Batches per seconds: 101.77, Global step:   3159, Validation Loss: 0.74, Validation Accuracy: 0.749
# Epoch: 4, Batches per seconds: 101.80, Global step:   3510, Validation Loss: 0.83, Validation Accuracy: 0.731
# Epoch: 5, Batches per seconds: 100.84, Global step:   3861, Validation Loss: 0.75, Validation Accuracy: 0.754
# Epoch: 5, Batches per seconds: 100.96, Global step:   4212, Validation Loss: 0.70, Validation Accuracy: 0.769
# Epoch: 6, Batches per seconds: 100.61, Global step:   4563, Validation Loss: 0.75, Validation Accuracy: 0.769
# Epoch: 6, Batches per seconds: 101.26, Global step:   4914, Validation Loss: 0.72, Validation Accuracy: 0.765
# Epoch: 7, Batches per seconds: 100.90, Global step:   5265, Validation Loss: 0.72, Validation Accuracy: 0.768
# Early stop criteria met
# Early stopping.

# %%
# NB: use ADAM optimizer
epochs = 10
batch_size = 64
learning_rate = 1e-3
early_stop_count = 4
dataloaders_z = load_cifar10(batch_size, trans_opt='x')

model_z = ModelZ(image_channels=3, num_classes=10)
trainer_z = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model_z,
    dataloaders_z
)
trainer_z.train()
# Out:
# Files already downloaded and verified
# Model X transform
# Files already downloaded and verified
# Files already downloaded and verified
# ModelZ(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (spatial_normalizer): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
#   (class_normalizer): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.7, inplace=False)
# )
# Epoch: 0, Batches per seconds: 70.60, Global step:    703, Validation Loss: 1.20, Validation Accuracy: 0.573
# Epoch: 0, Batches per seconds: 70.58, Global step:   1406, Validation Loss: 1.03, Validation Accuracy: 0.632
# Epoch: 1, Batches per seconds: 68.12, Global step:   2109, Validation Loss: 0.86, Validation Accuracy: 0.695
# Epoch: 1, Batches per seconds: 68.74, Global step:   2812, Validation Loss: 0.78, Validation Accuracy: 0.732
# Epoch: 2, Batches per seconds: 68.13, Global step:   3515, Validation Loss: 0.71, Validation Accuracy: 0.748
# Epoch: 2, Batches per seconds: 68.44, Global step:   4218, Validation Loss: 0.71, Validation Accuracy: 0.754
# Epoch: 3, Batches per seconds: 69.33, Global step:   4921, Validation Loss: 0.68, Validation Accuracy: 0.761
# Epoch: 3, Batches per seconds: 70.27, Global step:   5624, Validation Loss: 0.65, Validation Accuracy: 0.772
# Epoch: 4, Batches per seconds: 70.31, Global step:   6327, Validation Loss: 0.60, Validation Accuracy: 0.787
# Epoch: 4, Batches per seconds: 70.52, Global step:   7030, Validation Loss: 0.62, Validation Accuracy: 0.782
# Epoch: 5, Batches per seconds: 69.93, Global step:   7733, Validation Loss: 0.57, Validation Accuracy: 0.801
# Epoch: 5, Batches per seconds: 69.76, Global step:   8436, Validation Loss: 0.57, Validation Accuracy: 0.802
# Epoch: 6, Batches per seconds: 69.37, Global step:   9139, Validation Loss: 0.54, Validation Accuracy: 0.814
# Epoch: 6, Batches per seconds: 69.22, Global step:   9842, Validation Loss: 0.54, Validation Accuracy: 0.815
# Epoch: 7, Batches per seconds: 68.85, Global step:  10545, Validation Loss: 0.53, Validation Accuracy: 0.821
# Epoch: 7, Batches per seconds: 68.74, Global step:  11248, Validation Loss: 0.53, Validation Accuracy: 0.815
# Epoch: 8, Batches per seconds: 68.60, Global step:  11951, Validation Loss: 0.51, Validation Accuracy: 0.824
# Epoch: 8, Batches per seconds: 68.58, Global step:  12654, Validation Loss: 0.51, Validation Accuracy: 0.822
# Epoch: 9, Batches per seconds: 68.36, Global step:  13357, Validation Loss: 0.48, Validation Accuracy: 0.835
# Epoch: 9, Batches per seconds: 68.20, Global step:  14060, Validation Loss: 0.47, Validation Accuracy: 0.843

# %%
print("Model X")
#print_final_results(trainer_x)
print("Model Y")
#print_final_results(trainer_y)
print("Base Model")
#test_model(trainer_base)
print("Model Z")
print_final_results(trainer_z)
# Out:
# Model X
# Model Y
# Base Model
# Model Z
# Training Loss: 0.35, Training Accuracy: 0.884, Validation Loss: 0.47, Validation Accuracy: 0.842, Test Loss: 0.58, Test Accuracy: 0.804

# %%
plot_comparison(trainer_x, trainer_base,"3d_comparison")
#create_plots(trainer_y, "3b_validation")
#create_plots(trainer_base, "Base Trainer")
create_plots(trainer_z, "3e_validation")
