# %%
import importlib
import torch
import torch.nn as nn
from dataloaders import load_cifar10
import numpy as np

import trainer
import task2
import task3
import dataloaders
from trainer import Trainer, compute_loss_and_accuracy
from task2 import create_plots, test_model, print_results, ExampleModel
from task3 import ModelX, ModelY, ModelZ

trainer = importlib.reload(trainer)
task2 = importlib.reload(task2)
task3 = importlib.reload(task3)
dataloaders = importlib.reload(dataloaders)

torch.manual_seed(17)

# %%
epochs = 10
batch_size = 64
learning_rate = 1e-2
early_stop_count = 4
dataloaders = load_cifar10(batch_size)

model_base = ExampleModel(image_channels=3, num_classes=10)
trainer_base = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model_base,
    dataloaders
)
trainer_base.train()
# Out:
# Files already downloaded and verified
# Default transform
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Batches per seconds: 105.35, Global step:    351, Validation Loss: 2.30, Validation Accuracy: 0.097
# ...

# %%
epochs = 10
batch_size = 64
learning_rate = 1.5e-2
early_stop_count = 4
dataloaders_x = load_cifar10(batch_size, trans_opt='x')

model_x = ModelX(image_channels=3, num_classes=10)
trainer_x = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model_x,
    dataloaders_x
)
trainer_x.train()
# Out:
# Files already downloaded and verified
# Model X transform
# Files already downloaded and verified
# Files already downloaded and verified
# ModelX(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (spatial_normalizer): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
# ...

# %%
epochs = 10
batch_size = 64
learning_rate = 1.2e-3
early_stop_count = 4
dataloaders_y = load_cifar10(batch_size, trans_opt='y')

model_y = ModelY(image_channels=3, num_classes=10)
trainer_y = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model_y,
    dataloaders_y
)
trainer_y.train()
# Out:
# Files already downloaded and verified
# Model Y transform
# Files already downloaded and verified
# ModelY(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (spatial_normalizer): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
# ...

# %%
epochs = 10
batch_size = 64
learning_rate = 1e-3
early_stop_count = 4
dataloaders_z = load_cifar10(batch_size, trans_opt='x')

model_z = ModelZ(image_channels=3, num_classes=10)
trainer_z = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model_z,
    dataloaders_z
)
trainer_z.train()
# Out:
# Files already downloaded and verified
# Model X transform
# Files already downloaded and verified
# Files already downloaded and verified
# ModelZ(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (spatial_normalizer): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
# ...

# %%
print("Model X")
test_model(trainer_x)
print("Model Y")
test_model(trainer_y)
print("Base Model")
test_model(trainer_base)
print("Model Z")
test_model(trainer_z)
# Out:
# Model X
# Test Loss: 2.31, Test Accuracy: 0.100
# Model Y
# Test Loss: 0.75, Test Accuracy: 0.756
# Base Model
# Test Loss: 2.30, Test Accuracy: 0.100
# Model Z
# Test Loss: 0.58, Test Accuracy: 0.804

# %%
#create_plots(trainer_x, "Trainer X")
create_plots(trainer_y, "Trainer Y")
#create_plots(trainer_base, "Base Trainer")
